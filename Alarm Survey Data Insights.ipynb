# %%
import pandas as pd

# %%
pd.read_excel('Alarm Survey Data.xlsx')
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
df=pd.read_excel('Alarm Survey Data.xlsx')
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
df.sleep_quality.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       3.0
# 1       3.0
# 2       4.0
# 3       4.0
# 4       1.0
#        ...
# 6428    5.0
# 6429    4.0
# 6430    5.0
# 6431    5.0
# 6432    4.0
# Name: sleep_quality, Length: 6433, dtype: float64>

# %%
df.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: count, dtype: int64

# %%
df.isna()
# Out:
#       survey_id    age  number_of_children  activity_level  sleep_quality  \
# 0         False  False               False           False          False
# 1         False  False               False           False          False
# 2         False  False               False           False          False
# 3         False  False               False           False          False
# 4         False  False               False           False          False
# ...         ...    ...                 ...             ...            ...
# 6428      False  False               False           False          False
# 6429      False  False               False           False          False
# 6430      False  False               False           False          False
# 6431      False  False               False           False          False
# 6432      False  False               False           False          False
#
#       number_of_snoozes  alarm_rating
# 0                 False         False
# ...

# %%
df.isna().sum()
# Out:
# survey_id               0
# age                     0
# number_of_children      0
# activity_level          0
# sleep_quality         351
# number_of_snoozes       0
# alarm_rating            0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                 2.0  light_activity            NaN
# 18           19   38                 2.0  lightly active            NaN
# 23           24   24                 2.0     very active            NaN
# 26           27   25                 2.0  lightly active            NaN
# 28           29   29                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                 2.0     very active            NaN
# 6319       6320   44                 2.0  lightly active            NaN
# 6375       6309   32                 3.0           light            NaN
# 6377       6311   30                 2.0     very active            NaN
# 6386       6320   44                 2.0  lightly active            NaN
#
#       number_of_snoozes alarm_rating
# 10                    3      4 stars
# ...

# %%
df.sleep_quality.fillna(df.sleep_quality.mean(), inplace=True)
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
df.activity_level.value_counts()
# Out:
# activity_level
# active            2450
# lightly active    2289
# light_activity     691
# very active        669
# light              334
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df.activity_level = np.where(df.activity_level == 'light_activity', 'lightly active', df.activity_level)
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
df.activity_level.value_counts()
# Out:
# activity_level
# lightly active    2980
# active            2450
# very active        669
# light              334
# Name: count, dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6433.000000
# mean   3216.302192    29.069175            1.395616       4.232654
# std    1856.007409     7.472048            1.432192       0.819139
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes
# count        6433.000000
# mean            1.145811
# std             1.599481
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             2.000000
# max            19.000000

# %%
df[df.duplicated(keep=False)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6299       6300   31                 2.0          active            5.0
# 6300       6301   27                 2.0  lightly active            4.0
# 6301       6302   41                 3.0  lightly active            5.0
# 6302       6303   25                 0.0  lightly active            5.0
# 6303       6304   25                 1.0  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 6299                  0      3 stars
# ...

# %%
df[df.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6366       6300   31                 2.0          active            5.0
# 6367       6301   27                 2.0  lightly active            4.0
# 6368       6302   41                 3.0  lightly active            5.0
# 6369       6303   25                 0.0  lightly active            5.0
# 6370       6304   25                 1.0  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0           light            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 6366                  0      3 stars
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0           light            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'survey_id'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'number_of_children'}>,
#         <Axes: title={'center': 'sleep_quality'}>],
#        [<Axes: title={'center': 'number_of_snoozes'}>, <Axes: >]],
#       dtype=object)

# %%
df.sleep_quality.max() - df.sleep_quality.min()
# Out:
# 4.0

# %%
df.hist(bins=4)
# Out:
# array([[<Axes: title={'center': 'survey_id'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'number_of_children'}>,
#         <Axes: title={'center': 'sleep_quality'}>],
#        [<Axes: title={'center': 'number_of_snoozes'}>, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns

sns.histplot(df.sleep_quality)
# Out:
# <Axes: xlabel='sleep_quality', ylabel='Count'>

# %%
sns.histplot(df.sleep_quality)
# Out:
# <Axes: xlabel='sleep_quality', ylabel='Count'>

# %%
sns.histplot(df.sleep_quality, binwidth=1);

# %%
sns.boxplot(x=df.sleep_quality)
# Out:
# <Axes: xlabel='sleep_quality'>

# %%
sns.boxplot(x=df.sleep_quality, color='red')
# Out:
# <Axes: xlabel='sleep_quality'>

# %%
import numpy as np

q25, q50, q75 = np.percentile(df.sleep_quality, [25, 50, 75])
iqr = q75 - q25

min_sleep_quality = q25 - 1.5*iqr
max_sleep_quality = q75 + 1.5*iqr

min_sleep_quality, q25, q50, q75, max_sleep_quality
# Out:
# (2.5, 4.0, 4.0, 5.0, 6.5)

# %%
df[df.sleep_quality < 2.5]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 4             5   30                 1.0  lightly active            1.0
# 6             7   41                 5.5  lightly active            1.0
# 7             8   36                 5.5  lightly active            1.0
# 17           18   41                 5.5     very active            1.0
# 91           92   31                 2.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 5608       5609   37                 4.0          active            1.0
# 5981       5982   35                 4.0          active            1.0
# 6010       6011   22                 3.0  lightly active            1.0
# 6194       6195   23                 1.0  lightly active            1.0
# 6317       6318   24                 1.0          active            1.0
#
#       number_of_snoozes alarm_rating
# 4                     4      3 stars
# ...

# %%
mean = np.mean(df.sleep_quality)
sd = np.std(df.sleep_quality)

mean, sd
# Out:
# (4.229808906511005, 0.8194381363422354)

# %% [markdown]
# # There are no outliers
